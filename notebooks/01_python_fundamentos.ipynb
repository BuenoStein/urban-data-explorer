# %% [markdown]
# Conceitos

# %%
int = 14
float  = 1.55
str  = "Julia"
bool  = False

print(f"{int} tem {float} e {str}m de altura.")
# Out:
# 14 tem 1.55 e Juliam de altura.

# %%
# Operadores eu passo

# %%
#strip
palavra_buracos = " slk "

print(palavra_buracos.strip()) # remove esquerdo e direito
print(palavra_buracos.lstrip()) #left
print(palavra_buracos.rstrip()) #right

#split
objetos_separados = [ '1','4' '15']
print('1,4,15'.split()) 

#join
print(",".join(['a','b','c']))

#f-strings
#basicamente conseguir usar variaveis coisas
# Out:
# slk
# slk
#  slk
# ['1,4,15']
# a,b,c

# %%
lista = [1,2,3,4,5,6]
sublista = lista[0:4]
print(sublista)

lista.append(71)
print(lista)

lista.pop(6)
print(lista)

lista2=[4,5,21,532,6,4326,3]
lista2.sort()
print(lista2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5, 6, 71]
# [1, 2, 3, 4, 5, 6]
# [3, 4, 5, 6, 21, 532, 4326]

# %%
arvore = {
    "Risco Queda": "GRANDE",
    "Tamanho da Copa": "4821"
}

print(arvore.get("Risco Queda"))

print(arvore.keys())

print(arvore.values())

print(arvore.items())
# Out:
# GRANDE
# dict_keys(['Risco Queda', 'Tamanho da Copa'])
# dict_values(['GRANDE', '4821'])
# dict_items([('Risco Queda', 'GRANDE'), ('Tamanho da Copa', '4821')])

# %%
A = {1,12,3,54,5,2,4}
B = {1,45,21,5,1,5,51}

print(A | B)
print(A & B)
print(A - B)

A.add(6)
print(6 in A)

print(len(A and B))
# Out:
# {1, 2, 3, 4, 5, 12, 45, 51, 21, 54}
# {1, 5}
# {2, 3, 4, 12, 54}
# True
# 5

# %%
Pessoa1 = {"Nome": "Igor", "Idade": 3, "Nascionalidade": "Brasileiro"}
Pessoa2 = {"Nome": "Pedro", "Idade": 6, "Nascionalidade": "Brasileiro"}

if Pessoa1["Nome"] == Pessoa2["Nome"] :
    print("Nome CErto")
elif Pessoa1["Idade"] == Pessoa2["Idade"] :
    print("Idade certo")
else :
    print("todos errados")
# Out:
# Certo
